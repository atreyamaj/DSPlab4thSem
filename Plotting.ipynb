# %% [markdown]
# # Mathematical functions
#
# Following are some commonly used functions, where variables x and y can be numbers,
# vectors, or matrices.
# <html>
# <head>
# <style>
# table {
#     font-family: arial, sans-serif;
#     border: 1px solid black;
#     border-collapse: collapse;
#     width: 100%;
# }
#
# </style>
# </head>
# <body>
#
# <table style="width:100%">
#
#   <tr>
#     <td>cos(x)</td>
#     <td>Cosine</td>
#     <td>abs(x)</td>
#     <td>Absolute value</td>
#   </tr>
#
#   <tr>
#     <td>sin(x)</td>
#     <td>Sine</td>
#     <td>sign(x) </td>
#     <td>Signum function</td>
#   </tr>
#
#   <tr>
#     <td>tan(x) </td>
#     <td> Tangent</td>
#     <td>max(x)</td>
#     <td>Maximum value</td>
#   </tr>
#
#   <tr>
#     <td>arccos(x)   </td>
#     <td>Arc cosine </td>
#     <td>min(x)</td>
#     <td>Minimum value</td>
#   </tr>
#
#   <tr>
#     <td>arcsin(x)      </td>
#     <td> Arc sine</td>
#     <td>ceil(x)</td>
#     <td>Round towards +∞</td>
#   </tr>
#
#   <tr>
#     <td>arctan(x)  </td>
#     <td>Arc tangent  </td>
#     <td>floor(x)  </td>
#     <td>Round towards −∞ </td>
#
#
#   </tr>
#
#   <tr>
#     <td>exp(x)  </td>
#     <td>Exponential </td>
#     <td>round(x) </td>
#     <td>Round to nearest integer </td>
#   </tr>
#
#   <tr>
#     <td>sqrt(x)  </td>
#     <td>Square root    </td>
#     <td>remainder(x)   </td>
#     <td>Remainder after division     </td>
#   </tr>
#
#   <tr>
#     <td>log(x)   </td>
#     <td>Natural logarithm    </td>
#     <td>angle(x)    </td>
#     <td>Phase angle   </td>
#   </tr>
#
#   <tr>
#     <td>log10(x)  </td>
#     <td>Common logarithm  </td>
#     <td>conj(x)   </td>
#     <td>Complex conjugate     </td>
#   </tr>
#
# </table>
#
# </body>
# </html>
#
#
# Example 1 plots 'cosine' and 'sine' functions in the range [0 $2\pi$) usign subplots sharing x-axis and example 2 plots 'Signum' and 'Exponential' functions in the range [-1 1) usign subplots sharing y-axis.

# %%
# Example 1
import numpy as np 
import matplotlib.pyplot as pyplot

x=np.arange(0, 2*np.pi, np.pi/10)
y=np.cos(x)
z=np.sin(x)
f, axarr = pyplot.subplots(2, sharex=True)   #Sharing X-axis
axarr[0].stem(x,y)
axarr[0].set_title('Cosine plot')
axarr[1].stem(x,z)
axarr[1].set_title('Sine plot')
#print(z)
#pyplot.stem(x,y);
pyplot.show()

# %%
# Example 2
import numpy as np 
import matplotlib.pyplot as pyplot
x=np.arange(-1, 1, 0.1)
y=np.sign(x)
z=np.exp(x)
f, (ax1, ax2) = pyplot.subplots(1, 2, sharey=True)  #Sharing Y axis
ax1.stem(x,y)
ax1.set_title('Signum function')
ax2.stem(x,z)
ax2.set_title('Exponential function')

pyplot.show()

# %% [markdown]
# # Multiple data sets in one plot
#
# Multiple $(x, y)$ pairs arguments create multiple graphs with a single call to plot. For example, these statements plot three related functions of $x: y_1 = 2 cos(x), y_2 = cos(x)$, and $y_3 = 0.5cos(x)$, in the interval $0 ≤ x ≤ 2\pi$.
#
# ### Specifying line styles and colors
#
# It is possible to specify line styles, colors, and markers using the command specifie in Example 3.
#
#
# <html>
# <head>
# <style>
# table {
#     font-family: arial, sans-serif;
#     border: 1px solid black;
#     border-collapse: collapse;
#     width: 100%;
# }
#
# </style>
# </head>
# <body>
#
# <table style="width:100%">
#
#   <tr>
#     <th>Symbol</th>
#     <th>Color</th>
#     <th>Symbol</th>
#     <th>Line Style</th>
#     <th>Symbol</th>
#     <th>Marker</th>
#   </tr>
#
#   <tr>
#     <td>k</td>
#     <td>Black</td>
#     <td>-</td>
#     <td>Solid</td>
#     <td>,</td>
#     <td>pixel</td>
#   </tr>
#
#   <tr>
#     <td>r </td>
#     <td> Red</td>
#     <td>--</td>
#     <td>Dashed</td>
#     <td>o</td>
#     <td>circle</td>
#
#   </tr>
#
#   <tr>
#     <td>b </td>
#     <td> Blue</td>
#     <td>:</td>
#     <td>Dotted</td>
#     <td>+</td>
#     <td>Plus sign</td>
#   </tr>
#
#   <tr>
#     <td>g </td>
#     <td> Green</td>
#     <td>-.</td>
#     <td>Dash-dot</td>
#     <td>v</td>
#     <td>Triangle_down</td>
#   </tr>
#   <tr>
#     <td>c </td>
#     <td> Cyan</td>
#     <td></td>
#     <td></td>
#     <td>^</td>
#     <td>Triangle_up</td>
#   </tr>
#
#   <tr>
#     <td>m </td>
#     <td> Magenta</td>
#     <td></td>
#     <td></td>
#     <td>></td>
#     <td>Triangle_right</td>
#   </tr>
#
#   <tr>
#     <td>y </td>
#     <td> yellow</td>
#     <td></td>
#     <td></td>
#     <td>s</td>
#     <td>Square</td>
#   </tr>
#
#   <tr>
#     <td></td>
#     <td></td>
#     <td></td>
#     <td></td>
#     <td>p</td>
#     <td>Pentagon</td>
#   </tr>
#
#    <tr>
#     <td></td>
#     <td></td>
#     <td></td>
#     <td></td>
#     <td>*</td>
#     <td>Star</td>
#   </tr>
#
#
#
#
#
#   </table>
#
# </body>
# </html>

# %%
# Example 3
import numpy as np 
import matplotlib.pyplot as pyplot

x=np.arange(0, 2*np.pi, np.pi/15)
y1=2*np.cos(x)
y2=np.cos(x)
y3=0.5*np.cos(x)
fig, ax = pyplot.subplots()

#Dash style dashes = [20, 5, 20, 5]  means 20 points on, 5 off, 20 on, 5 off
line1 = ax.plot(x, y1, '--', linewidth=2, dashes=[20, 5, 20, 5], label='2cos(x)')

#Line styles
line2 = ax.plot(x,y2, linestyle='--', color='r', linewidth=3, label='cos(x)')

#Marker style
line3 = ax.plot(x,y3, marker='v', linewidth=1, label='0.5cos(x)')

ax.legend(loc='lower right')

pyplot.show()

# %% [markdown]
# ## Log plot

# %%
# log y axis
import numpy as np
import matplotlib.pyplot as plt
t = np.arange(0.01, 20.0, 0.01)
plt.semilogy(t, np.exp(-t/5.0))
plt.title('semilogy')
plt.grid(True)
plt.show()

# %%
# log x axis
import numpy as np
import matplotlib.pyplot as plt
t = np.arange(0.01, 20.0, 0.01)
plt.semilogx(t, np.sin(2*np.pi*t))
plt.title('semilogx')
plt.grid(True)
plt.show()

# %%
# log x and y axis
import numpy as np
import matplotlib.pyplot as plt
t = np.arange(0.01, 20.0, 0.01)
plt.loglog(t, 20*np.exp(-t/10.0), basex=2)
plt.grid(True)
plt.title('loglog base 2 on x')
plt.show()

# %% [markdown]
# ## Plotting Histogram
#
# The NumPy histogram function applied to an array returns a pair of vectors: the histogram of the array and the vector of bins. Beware: matplotlib also has a function to build histograms (called hist, as in Matlab) that differs from the one in NumPy. The main difference is that pylab.hist plots the histogram automatically, while numpy.histogram only generates the data.

# %%
import numpy as np
import matplotlib.pyplot as plt
# Build a vector of 10000 normal deviates with variance 0.5^2 and mean 2
mu, sigma = 2, 0.5
v = np.random.normal(mu,sigma,10000)
# Plot a normalized histogram with 50 bins
plt.hist(v, bins=50, normed=1)       # matplotlib version (plot)
plt.show()
# Out:
# /home/dsplab/.local/lib/python3.4/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
# Compute the histogram with numpy and then plot it
(n, bins) = np.histogram(v, bins=50, normed=True)  # NumPy version (no plot)
plt.plot(.5*(bins[1:]+bins[:-1]), n)
plt.show()
# Out:
# /usr/local/lib/python3.4/dist-packages/ipykernel_launcher.py:2: VisibleDeprecationWarning: Passing `normed=True` on non-uniform bins has always been broken, and computes neither the probability density function nor the probability mass function. The result is only correct if the bins are uniform, when density=True will produce the same result anyway. The argument will be removed in a future version of numpy.

# %% [markdown]
# ## Plotting histogram for an image

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

img=mpimg.imread('123.png','png')
imgplot = plt.imshow(img)
plt.show()

(n, bins) = np.histogram(img, bins=255)  # NumPy version (no plot)
plt.plot(.5*(bins[1:]+bins[:-1]), n)
plt.show()
